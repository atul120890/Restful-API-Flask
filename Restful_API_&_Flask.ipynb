# %% [markdown]
# Restful API & Flask

# %% [markdown]
# '''Q1.What is a RESTful API.
#
# Ans-A RESTful API in Python is an API (Application Programming Interface) built using Python that follows REST principles — allowing clients to interact with a web service using HTTP methods like GET, POST, PUT, and DELETE.
# In Python, RESTful APIs are commonly built using frameworks like:
#
# Flask (lightweight, flexible)
#
# FastAPI (modern, fast, type-hint friendly)
#
# Django REST Framework (DRF) (powerful, good for large apps)'''
#
# '''Q2.Explain the concept of API specification
#
# Ans-An API specification is a detailed, formal description of how an API behaves — it tells developers what the API does, how to use it, and what to expect when interacting with it.'''
#
# '''Q3.What is Flask, and why is it popular for building APIs
#
# Ans-Flask is a lightweight, open-source Python web framework that's widely used for building web applications and RESTful APIs. It's popular because it's simple, flexible, and easy to get started with, especially for small to medium-sized projects.'''
#
# '''Q4.What is routing in Flask
#
# Ans-Routing in Flask is the process of matching a URL to a Python function that handles the request — this is how Flask decides what code to run when someone visits a certain URL.'''
#
# '''Q5.How do you create a simple Flask application
#
# Ans-Creating a simple Flask application is easy — it just takes a few lines of code. Here's a step-by-step guide to get you started.
# Flask(__name__): Creates the app.
#
# @app.route('/'): Defines a route for /.
#
# home(): Function that runs when that route is accessed.
#
# debug=True: Enables hot-reloading and helpful error messages during development.'''
#
# '''Q6.What are HTTP methods used in RESTful APIs
#
# In RESTful APIs, HTTP methods define what kind of action is being performed on a resource (like data stored on a server)
#
# Main HTTP Methods in RESTful APIs:
# Method     	Purpose                      	Description
# GET	     Retrieve data	         Used to request data from a server (read-only).
# POST  	Create a new resource	    Sends data to the server to create something new.
# PUT  	Update an existing resource 	   Replaces a resource entirely with new data.
# PATCH    	Partially update a resource	  Updates only part of a resource.
# DELETE	Delete a resource	Removes    a resource from the server'''
#
# '''Q7.What is the purpose of the @app.route() decorator in Flask
#
# Ans-The @app.route() decorator in Flask is used to define a route — that is, it tells Flask which URL should trigger a specific function.
#
# Purpose:
# It maps a URL path to a Python function, known as a view function, so that when a client (like a web browser or an API call) accesses that URL, Flask runs the associated function.'''
#
# '''Q8.What is the difference between GET and POST HTTP methods
#
# Ans-The GET and POST HTTP methods are both used to interact with resources on a server, but they have different purposes and behaviors.use GET for retrieving data without side effects, and POST for sending data to the server to modify or create resources.'''
#
# '''Q9.How do you handle errors in Flask APIs
#
# Ans-Handling errors in Flask APIs is essential for creating robust and user-friendly applications. Flask provides several mechanisms to manage errors, ranging from built-in error handling to custom error responses.
# Use abort() to raise predefined HTTP errors
#
# Use @app.errorhandler() for custom error handling of specific status codes.
#
# Manually return error responses using make_response().
#
# Use validation libraries like Marshmallow to handle request data errors.
#
# Use global error handling for general checks and logging'''
#
# '''Q10.How do you connect Flask to a SQL database.
#
# Ans-To connect Flask to an SQL database, you typically use an Object-Relational Mapping (ORM) tool like SQLAlchemy or a simpler database connection library like SQLite for smaller projects.
#
# Here’s a step-by-step guide on how to connect Flask to an SQL database using SQLAlchemy (which works with many SQL databases like MySQL, PostgreSQL, SQLite, etc.).
#
# Install Flask-SQLAlchemy to interact with the database.
#
# Configure the database URI to connect to your SQL database (e.g., SQLite, PostgreSQL, MySQL).
#
# Define models representing database tables using SQLAlchemy.
#
# Use db.session.add() and db.session.commit() to insert and save data.
#
# Query the database using User.query.all() or similar methods.'''
#
# '''Q11.What is the role of Flask-SQLAlchemy
# Flask-SQLAlchemy is an extension for Flask that simplifies the integration of SQLAlchemy, a powerful Object Relational Mapper (ORM), with Flask applications. It provides a set of tools and utilities that make it easier to work with databases in Flask, abstracting many of the complexities involved in database interaction.
#
# Here are the main roles and features of Flask-SQLAlchemy:
#
# Database Integration: It connects Flask with a database (usually SQL-based, such as SQLite, PostgreSQL, or MySQL) by providing an ORM layer to map Python objects to database tables.
#
# Simplified Database Setup: Flask-SQLAlchemy helps you configure the connection between Flask and the database, often just requiring a database URI to set up the connection.
#
# Object-Relational Mapping (ORM): Using SQLAlchemy’s ORM, Flask-SQLAlchemy allows you to interact with the database in terms of Python objects. You can define your database schema in Python classes, which SQLAlchemy automatically maps to tables in your database.
#
# Session Management: Flask-SQLAlchemy handles the creation and management of sessions, making it easier to query and manipulate data in a transactional context.
#
# Automatic Schema Generation: Flask-SQLAlchemy can automatically generate tables in the database based on the classes defined in your application, saving you from writing raw SQL.
#
# Querying: It provides an intuitive way to perform queries and filter data using Python objects, rather than writing raw SQL queries directly.'''
#
# '''Q12.What are Flask blueprints, and how are they useful.
#
# Flask blueprints are a way to organize and structure your Flask application by breaking it into modular components. They allow you to define routes, views, static files, templates, and other functionality in separate, reusable modules, making it easier to manage complex applications
#
# Benefits of Using Flask Blueprints:
# Better Organization: Blueprints allow you to split up your app into logical sections (e.g., user-related views, product-related views), making the codebase more organized and maintainable.
#
# Code Reusability: If you have a common feature (like user authentication) that you want to use in multiple projects, you can create a blueprint for it and simply reuse it.
#
# Ease of Testing: Modular blueprints can make testing easier since you can test each blueprint in isolation rather than having to test the entire application at once.
#
# Clear Separation: They provide a clear separation of different parts of your application, reducing complexity as your application grows'''
#
# '''Q13.What is the purpose of Flask's request object
#
# Ans-The request object in Flask is an essential part of handling HTTP requests. It allows you to access various parts of the incoming request, such as form data, query parameters, headers, cookies, files, and other information sent from the client to the server
# Key Attributes and Methods of the request Object:
# request.method: The HTTP method of the request (e.g., 'GET', 'POST').
#
# request.args: The query parameters from the URL (like ?key=value).
#
# request.form: The form data from POST requests.
#
# request.json: The parsed JSON data from the request body (useful for APIs).
#
# request.files: The files uploaded with the request.
#
# request.headers: The HTTP headers of the request.
#
# request.cookies: The cookies sent with the request.
#
# request.path: The path of the request URL.
#
# request.remote_addr: The IP address of the client making the request.'''
#
# '''Q14.How do you create a RESTful API endpoint using Flask.
#
# Ans-Creating a RESTful API endpoint using Flask involves defining routes that handle HTTP requests (GET, POST, PUT, DELETE, etc.) and respond with JSON data. Below is a step-by-step guide to creating a basic RESTful API endpoint using Flask:
# created a simple RESTful API in Flask with basic CRUD (Create, Read, Update, Delete) operations. This is a foundational structure that you can build on to create more complex APIs, add error handling, authentication, and more'''
#
# '''Q15.What is the purpose of Flask's jsonify() function.
#
# ans-Flask's jsonify() function is used to create a JSON response from Python data structures (such as dictionaries, lists, etc.). It converts the Python objects into JSON format and sets the appropriate Content-Type header (application/json), making it easier to return JSON responses from your Flask routes.
#
# Key Purposes of jsonify():
# Convert Python Objects to JSON:
# The jsonify() function converts Python data structures like dictionaries, lists, or tuples into a JSON-formatted response. This is particularly useful for APIs where you need to return data in JSON format.
#
# Set the Correct Content-Type:
# When Flask returns a JSON response, it automatically sets the Content-Type header to application/json, signaling that the response body is in JSON format. This is done automatically by jsonify().
#
# Handling Complex Data Types:
# jsonify() can handle complex data types, including nested dictionaries or lists, and properly convert them to JSON.'''
#
# '''Q16.Explain Flask’s url_for() function
#
# Ans-Flask's url_for() function is used to generate URLs for specific routes defined in your Flask application. Instead of hardcoding URLs in your templates or views, url_for() allows you to dynamically generate URLs based on the name of the route or endpoint. This is useful because it keeps your URLs flexible and avoids issues with changing URLs manually'''
#
# '''Q17.DFM How does Flask handle static files (CSS, JavaScript, etc.)
#
# In Flask, static files (such as CSS, JavaScript, images, and other files that do not change dynamically) are handled by the static folder. Flask automatically serves files placed in this folder and provides a convenient way to link to them in your HTML templates.
#
# How Flask Handles Static Files:
# Static Folder:
# By default, Flask looks for static files in a folder named static at the root level of your application directory. When you start the Flask application, Flask serves static files from this folder at the URL path /static/.
#
# Accessing Static Files:
# You can access static files by referring to their path relative to the static folder. For example, if you have a file styles.css in the static/css/ folder, you can reference it in your templates as /static/css/styles.css.
#
# Serving Static Files:
# Flask automatically handles serving static files like CSS, JavaScript, and images, so you don’t have to write custom routes for each file. All files inside the static folder are directly accessible by URL paths starting with /static/.'''
#
# '''Q18.What is an API specification, and how does it help in building a Flask
#
# Ans-.An API specification is a detailed document or description that defines the structure, endpoints, methods, inputs, outputs, and behavior of an API (Application Programming Interface). It acts as a blueprint for how the API should function, providing clear guidelines for both the development and consumption of the API'''
#
# HTTP status codes are standardized codes returned by a web server to indicate the result of an HTTP request. These codes are used to communicate the outcome of a request, providing information about whether the request was successful, if there was an error, or if additional actions are needed by the client.
#
# HTTP status codes are categorized into five classes, each represented by the first digit of the code:
#
# HTTP status codes are a vital part of any API, including Flask APIs. They provide a way for your API to communicate the result of an HTTP request, including success, client-side errors, or server-side errors. Correctly using HTTP status codes ensures that your API is user-friendly, easy to debug, and follows industry standards for API design.'''
#
# '''Q19.What are HTTP status codes, and why are they important in a Flask API
#
# ans-HTTP status codes are standardized three-digit codes returned by a web server to indicate the result of a client's request. They are part of the HTTP protocol and help both humans and applications understand what happened after a request was made
# Why HTTP Status Codes Are Important in a Flask API:
# Communicate Results Clearly:
# They let clients (e.g., browsers, mobile apps) know whether a request was successful, invalid, unauthorized, or failed due to a server issue.
#
# Enable Better Error Handling:
# Clients can react appropriately—for example, retry on 503, prompt login on 401, or show "not found" for 404.
#
# Improve API Usability:
# Well-structured APIs with proper status codes are easier to use, debug, and integrate.
#
# Follow REST Standards:
# RESTful API design relies heavily on meaningful use of HTTP status codes for proper client-server communication.'''
#
# '''Q20.How do you handle POST requests in Flask
#
# Ans-To handle POST requests in Flask, you define a route with the POST method and use Flask's request object to access incoming data (usually JSON or form data).
#
# Basic Steps to Handle a POST Request in Flask:
# Import Required Modules
#
# Set Route with methods=['POST']
#
# Access Incoming Data Using request
#
# Return a Response'''
#
# '''Q21.How would you secure a Flask API
#
# Ans-Securing a Flask API involves implementing various measures to protect it from unauthorized access, data breaches, and common vulnerabilities like injection attacks or cross-site request forgery. Here are the key strategies
# 1.Authentication & Authorization
# 2. Use HTTPS
# 3. Input Validation & Sanitization
# 4. Rate Limiting
# 5. Cross-Origin Resource Sharing (CORS)
# 6. Avoid Exposing Sensitive Info
# 7. Secure API Tokens & Secrets
# 8. Logging & Monitoring
# 9. Session Protection (if using sessions)
# 10. Use Security Headers'''
#
# '''Q22.What is the significance of the Flask-RESTful extension
#
# Ans-The Flask-RESTful extension simplifies building RESTful APIs with Flask by providing a structured, class-based way to define API resources and handle HTTP methods like GET, POST, PUT, and DELETE.
# Class-Based Views
#
# You define resources as Python classes, where each HTTP method is a method in the class (get(), post(), etc.).
#
# This keeps code modular and clean.
#
# Automatic Routing
#
# You can easily map resources to URLs using api.add_resource().
#
# Request Parsing with reqparse
#
# Helps validate and extract arguments from incoming requests.
#
# Automatic JSON Responses
#
# Responses from resource methods are automatically converted to JSON.
#
# Better Error Handling
#
# Includes standardized error messages and status codes.'''
#
# '''Q23. What is the role of Flask’s session object?
#
# Ans-The session object in Flask is used to store information about a user's interaction with the web application across multiple requests. It allows you to keep track of data like user login status, preferences, or other session-specific variables without needing to store them in the browser or pass them in every request.'''

# %% [markdown]
# Practical

# %%
#Q1.DHow do you create a basic Flask application
from flask import Flask

app = Flask(__name__)

@app.route('/')
def home():
    return 'Hello, Flask!'

if __name__ == '__main__':
    app.run(debug=True)

# %%
#Q2.How do you serve static files like images or CSS in Flask

# Create a static Directory
/project
│
├── app.py
├── static/
│   ├── style.css
│   └── logo.png

# %%
#Q3 How do you define different routes with different HTTP methods in Flask
from flask import Flask, request

app = Flask(__name__)

# Route for GET requests
@app.route('/get-example', methods=['GET'])
def get_example():
    return 'This is a GET request'

# Route for POST requests
@app.route('/post-example', methods=['POST'])
def post_example():
    data = request.form.get('data')
    return f'Received POST data: {data}'

# Route that handles both GET and POST
@app.route('/both-example', methods=['GET', 'POST'])
def both_example():
    if request.method == 'POST':
        return 'Handling POST request'
    return 'Handling GET request'

if __name__ == '__main__':
    app.run(debug=True)

# %%
#Q4 How do you render HTML templates in Flask

from flask import Flask, render_template

app = Flask(__name__)

@app.route('/')
def home():
    return render_template('index.html', name='Flask User')

if __name__ == '__main__':
    app.run(debug=True)

# %%
#Q5 How do you create a simple Flask application4

from flask import Flask

app = Flask(__name__)

@app.route('/')
def home():
    return "Hello, Flask!"

if __name__ == '__main__':
    app.run(debug=True)

# %%
#Q6.What are HTTP methods used in RESTful APIs
from flask import Flask, request, render_template

app = Flask(__name__)

@app.route('/submit', methods=['GET', 'POST'])
def submit():
    if request.method == 'POST':
        name = request.form['name']
        email = request.form['email']
        return f"Received: {name}, {email}"
    return render_template('form.html')

# %%
<form method="POST">
  Name: <input type="text" name="name"><br>
  Email: <input type="email" name="email"><br>
  <input type="submit" value="Submit">
</form>

# %%
#Q7. How can you validate form data in Flask4
pip install flask-wtf

# %%
from flask import Flask, render_template
from flask_wtf import FlaskForm
from wtforms import StringField, SubmitField
from wtforms.validators import DataRequired, Length

app = Flask(__name__)
app.secret_key = 'secret'

class MyForm(FlaskForm):
    name = StringField('Name', validators=[DataRequired(), Length(min=3)])
    submit = SubmitField('Submit')

@app.route('/form', methods=['GET', 'POST'])
def form():
    form = MyForm()
    if form.validate_on_submit():
        return f"Welcome, {form.name.data}!"
    return render_template('form.html', form=form)

# %%
#Q8 How do you manage sessions in Flask
from flask import Flask, session

app = Flask(__name__)
app.secret_key = 'your_secret_key'  # Required for session security

# %%
#Q9. How do you redirect to a different route in Flask
@app.route('/login/<username>')
def login(username):
    return redirect(url_for('profile', user=username))

@app.route('/profile/<user>')
def profile(user):
    return f"Hello, {user}!"

# %%
#Q10. How do you handle errors in Flask (e.g., 404)

from flask import Flask, render_template

app = Flask(__name__)

@app.errorhandler(404)
def page_not_found(e):
    return render_template('404.html'), 404

@app.errorhandler(500)
def internal_server_error(e):
    return render_template('500.html'), 500

# %%
#Q11. How do you structure a Flask app using Blueprint
/my_flask_app
    /app
        __init__.py
        /auth
            __init__.py
            routes.py
        /blog
            __init__.py
            routes.py
        /templates
        /static
    run.py

# %%
#Q12How do you define a custom Jinja filter in Flask
# app/__init__.py
from flask import Flask
from .filters import capitalize_words

def create_app():
    app = Flask(__name__)

    # Register custom Jinja filter
    app.jinja_env.filters['capitalize_words'] = capitalize_words

    return app

# %%
#Q13 How can you redirect with query parameters in Flask
from flask import Flask, redirect, url_for

app = Flask(__name__)

@app.route('/')
def home():
    user_id = 123  # Example user ID
    return redirect(url_for('profile', user_id=user_id))

@app.route('/profile')
def profile():
    user_id = request.args.get('user_id')  # Get the query parameter
    return f"Profile page of user {user_id}"

if __name__ == '__main__':
    app.run(debug=True)

# %%
#Q14.How do you return JSON responses in Flask

from flask import Flask, jsonify

app = Flask(__name__)

@app.route('/data')
def data():
    data = {
        'name': 'Alice',
        'age': 30,
        'city': 'New York'
    }
    return jsonify(data)

if __name__ == '__main__':
    app.run(debug=True)

# %%
#Q15.How do you capture URL parameters in Flask?
from flask import Flask

app = Flask(__name__)

# Capture a dynamic part of the URL
@app.route('/user/<username>')
def show_user(username):
    return f'User: {username}'

if __name__ == '__main__':
    app.run(debug=True)

# %%
from flask import Flask, request

app = Flask(__name__)

@app.route('/user/<username>')
def show_user(username):
    return f'User: {username}'

@app.route('/search')
def search():
    query = request.args.get('q')
    sort = request.args.get('sort', 'asc')
    return f'Search query: {query}, Sort: {sort}'

if __name__ == '__main__':
    app.run(debug=True)
